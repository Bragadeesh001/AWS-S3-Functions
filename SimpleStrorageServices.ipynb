# %% [markdown]
# ## AWS S3

# %%
#installing boto3

# !pip install boto3
# !pip install s3fs

# %%
#importing necessary libraries

import boto3
import pandas as pd

# %%
#Connecting to S3

s3=boto3.resource(
    service_name='s3',
    region_name='ap-south-1',
    aws_access_key_id='AKIAUN4WLJCLHABKEBMD',
    aws_secret_access_key='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'
)

# %%
#Printing buckeet name present

for bucket in s3.buckets.all():
  print(bucket)
# Out:
# s3.Bucket(name='bragadeesh.test1')

# %%
#key environment (so that we dont have to use these parameters again n again)

import os
os.environ['aws_default_region']='ap-south-1'
os.environ['aws_access_key_id']='AKIAUN4WLJCLHABKEBMD'
os.environ['aws_secret_access_key']='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'

# %%
#Seeing objects in our bucket

for obj in s3.Bucket('bragadeesh.test1').objects.all():
  print(obj)

# %%
#Creating table using pandas

table={'Name':['Bragadeesh','Sreeleka','Ravi','Guna'],'Rool_id':[1234,2345,3456,4567],'CGPA':[7.1,7.5,7.0,7.6]}
data=pd.DataFrame(table)
data.to_csv('data.csv')
print(data)
# Out:
#          Name  Rool_id  CGPA
# 0  Bragadeesh     1234   7.1
# 1    Sreeleka     2345   7.5
# 2        Ravi     3456   7.0
# 3        Guna     4567   7.6

# %%
#UpLoad the dataframe to s3 bucket

s3.Bucket('bragadeesh.test1').upload_file(Filename='data.csv',Key='data.csv')

# %%
#lets look object in buckect after uploading

for obj in s3.Bucket('bragadeesh.test1').objects.all():
  print(obj)
# Out:
# s3.ObjectSummary(bucket_name='bragadeesh.test1', key='data.csv')

# %%
#Getting specific file from bucket

data=s3.Bucket('bragadeesh.test1').Object('data.csv').get()
data=pd.read_csv(data['Body'],index_col=0)
data
# Out:
#          Name  Rool_id  CGPA
# 0  Bragadeesh     1234   7.1
# 1    Sreeleka     2345   7.5
# 2        Ravi     3456   7.0
# 3        Guna     4567   7.6

# %%
#Delete files in bucket

s3.Bucket('bragadeesh.test1').Object('data.csv').delete()
# Out:
# {'DeleteMarker': True,
#  'ResponseMetadata': {'HTTPHeaders': {'date': 'Wed, 10 Aug 2022 15:32:08 GMT',
#    'server': 'AmazonS3',
#    'x-amz-delete-marker': 'true',
#    'x-amz-id-2': '31CUSRQsvxNADmJ/yWv+HSXzIaHzulqIyECM7K3cDLtenDmt4Dp3z7aiUf6dTcGCNGTkBxN91tM=',
#    'x-amz-request-id': '5VZ0RQHVQV3RX2VX',
#    'x-amz-version-id': 'yYzaWzqTZVj_Vw4CKFzsIu.zhbSXLFrm'},
#   'HTTPStatusCode': 204,
#   'HostId': '31CUSRQsvxNADmJ/yWv+HSXzIaHzulqIyECM7K3cDLtenDmt4Dp3z7aiUf6dTcGCNGTkBxN91tM=',
#   'RequestId': '5VZ0RQHVQV3RX2VX',
#   'RetryAttempts': 0},
#  'VersionId': 'yYzaWzqTZVj_Vw4CKFzsIu.zhbSXLFrm'}

# %%
# see objects in bucket after deleting

for obj in s3.Bucket('bragadeesh.test1').objects.all():
  print(obj)
